# %%
from sklearn.datasets import load_linnerud
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

data = load_linnerud()
data
# Out:
# {'data': array([[  5., 162.,  60.],
#         [  2., 110.,  60.],
#         [ 12., 101., 101.],
#         [ 12., 105.,  37.],
#         [ 13., 155.,  58.],
#         [  4., 101.,  42.],
#         [  8., 101.,  38.],
#         [  6., 125.,  40.],
#         [ 15., 200.,  40.],
#         [ 17., 251., 250.],
#         [ 17., 120.,  38.],
#         [ 13., 210., 115.],
#         [ 14., 215., 105.],
#         [  1.,  50.,  50.],
#         [  6.,  70.,  31.],
#         [ 12., 210., 120.],
#         [  4.,  60.,  25.],
#         [ 11., 230.,  80.],
#         [ 15., 225.,  73.],
#         [  2., 110.,  43.]]),
#  'feature_names': ['Chins', 'Situps', 'Jumps'],
#  'target': array([[191.,  36.,  50.],
#         [189.,  37.,  52.],
#         [193.,  38.,  58.],
#         [162.,  35.,  62.],
#         [189.,  35.,  46.],
#         [182.,  36.,  56.],
#         [211.,  38.,  56.],
#         [167.,  34.,  60.],
#         [176.,  31.,  74.],
#         [154.,  33.,  56.],
#         [169.,  34.,  50.],
#         [166.,  33.,  52.],
#         [154.,  34.,  64.],
#         [247.,  46.,  50.],
#         [193.,  36.,  46.],
#         [202.,  37.,  62.],
#         [176.,  37.,  54.],
#         [157.,  32.,  52.],
#         [156.,  33.,  54.],
#         [138.,  33.,  68.]]),
#  'target_names': ['Weight', 'Waist', 'Pulse'],
#  'frame': None,
#  'DESCR': '.. _linnerrud_dataset:\n\nLinnerrud dataset\n-----------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20\n    :Number of Attributes: 3\n    :Missing Attribute Values: None\n\nThe Linnerud dataset is a multi-output regression dataset. It consists of three\nexercise (data) and three physiological (target) variables collected from\ntwenty middle-aged men in a fitness club:\n\n- *physiological* - CSV containing 20 observations on 3 physiological variables:\n   Weight, Waist and Pulse.\n- *exercise* - CSV containing 20 observations on 3 exercise variables:\n   Chins, Situps and Jumps.\n\n.. topic:: References\n\n  * Tenenhaus, M. (1998). La regression PLS: theorie et pratique. Paris:\n    Editions Technic.\n',
#  'data_filename': 'linnerud_exercise.csv',
#  'target_filename': 'linnerud_physiological.csv',
#  'data_module': 'sklearn.datasets.data'}

# %%
df_features = data.feature_names
df_features
# Out:
# ['Chins', 'Situps', 'Jumps']

# %%
df_data = pd.DataFrame(data.data, columns = df_features)
df_data
# Out:
#     Chins  Situps  Jumps
# 0     5.0   162.0   60.0
# 1     2.0   110.0   60.0
# 2    12.0   101.0  101.0
# 3    12.0   105.0   37.0
# 4    13.0   155.0   58.0
# 5     4.0   101.0   42.0
# 6     8.0   101.0   38.0
# 7     6.0   125.0   40.0
# 8    15.0   200.0   40.0
# 9    17.0   251.0  250.0
# 10   17.0   120.0   38.0
# 11   13.0   210.0  115.0
# 12   14.0   215.0  105.0
# 13    1.0    50.0   50.0
# 14    6.0    70.0   31.0
# 15   12.0   210.0  120.0
# 16    4.0    60.0   25.0
# 17   11.0   230.0   80.0
# 18   15.0   225.0   73.0
# 19    2.0   110.0   43.0

# %%
df_labels = pd.DataFrame(data.target, columns = ['Weight', 'Waist', 'Pulse'])
df_labels
# Out:
#     Weight  Waist  Pulse
# 0    191.0   36.0   50.0
# 1    189.0   37.0   52.0
# 2    193.0   38.0   58.0
# 3    162.0   35.0   62.0
# 4    189.0   35.0   46.0
# 5    182.0   36.0   56.0
# 6    211.0   38.0   56.0
# 7    167.0   34.0   60.0
# 8    176.0   31.0   74.0
# 9    154.0   33.0   56.0
# 10   169.0   34.0   50.0
# 11   166.0   33.0   52.0
# 12   154.0   34.0   64.0
# 13   247.0   46.0   50.0
# 14   193.0   36.0   46.0
# 15   202.0   37.0   62.0
# 16   176.0   37.0   54.0
# 17   157.0   32.0   52.0
# 18   156.0   33.0   54.0
# 19   138.0   33.0   68.0

# %%
data = pd.concat([df_data, df_labels], axis=1)
data
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 0     5.0   162.0   60.0   191.0   36.0   50.0
# 1     2.0   110.0   60.0   189.0   37.0   52.0
# 2    12.0   101.0  101.0   193.0   38.0   58.0
# 3    12.0   105.0   37.0   162.0   35.0   62.0
# 4    13.0   155.0   58.0   189.0   35.0   46.0
# 5     4.0   101.0   42.0   182.0   36.0   56.0
# 6     8.0   101.0   38.0   211.0   38.0   56.0
# 7     6.0   125.0   40.0   167.0   34.0   60.0
# 8    15.0   200.0   40.0   176.0   31.0   74.0
# 9    17.0   251.0  250.0   154.0   33.0   56.0
# 10   17.0   120.0   38.0   169.0   34.0   50.0
# 11   13.0   210.0  115.0   166.0   33.0   52.0
# 12   14.0   215.0  105.0   154.0   34.0   64.0
# 13    1.0    50.0   50.0   247.0   46.0   50.0
# 14    6.0    70.0   31.0   193.0   36.0   46.0
# 15   12.0   210.0  120.0   202.0   37.0   62.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 17   11.0   230.0   80.0   157.0   32.0   52.0
# 18   15.0   225.0   73.0   156.0   33.0   54.0
# 19    2.0   110.0   43.0   138.0   33.0   68.0

# %%
data.columns
# Out:
# Index(['Chins', 'Situps', 'Jumps', 'Weight', 'Waist', 'Pulse'], dtype='object')

# %%
df2 = pd.concat([data['Chins'], data['Situps'], data['Jumps'], data['Waist']], axis=1)
df2
# Out:
#     Chins  Situps  Jumps  Waist
# 0     5.0   162.0   60.0   36.0
# 1     2.0   110.0   60.0   37.0
# 2    12.0   101.0  101.0   38.0
# 3    12.0   105.0   37.0   35.0
# 4    13.0   155.0   58.0   35.0
# 5     4.0   101.0   42.0   36.0
# 6     8.0   101.0   38.0   38.0
# 7     6.0   125.0   40.0   34.0
# 8    15.0   200.0   40.0   31.0
# 9    17.0   251.0  250.0   33.0
# 10   17.0   120.0   38.0   34.0
# 11   13.0   210.0  115.0   33.0
# 12   14.0   215.0  105.0   34.0
# 13    1.0    50.0   50.0   46.0
# 14    6.0    70.0   31.0   36.0
# 15   12.0   210.0  120.0   37.0
# 16    4.0    60.0   25.0   37.0
# 17   11.0   230.0   80.0   32.0
# 18   15.0   225.0   73.0   33.0
# 19    2.0   110.0   43.0   33.0

# %%
#Splitting the data into training and test test
X = df2.iloc[:,0:3].values
y = df2.iloc[:,3].values

# %%
X
# Out:
# array([[  5., 162.,  60.],
#        [  2., 110.,  60.],
#        [ 12., 101., 101.],
#        [ 12., 105.,  37.],
#        [ 13., 155.,  58.],
#        [  4., 101.,  42.],
#        [  8., 101.,  38.],
#        [  6., 125.,  40.],
#        [ 15., 200.,  40.],
#        [ 17., 251., 250.],
#        [ 17., 120.,  38.],
#        [ 13., 210., 115.],
#        [ 14., 215., 105.],
#        [  1.,  50.,  50.],
#        [  6.,  70.,  31.],
#        [ 12., 210., 120.],
#        [  4.,  60.,  25.],
#        [ 11., 230.,  80.],
#        [ 15., 225.,  73.],
#        [  2., 110.,  43.]])

# %%
y
# Out:
# array([36., 37., 38., 35., 35., 36., 38., 34., 31., 33., 34., 33., 34.,
#        46., 36., 37., 37., 32., 33., 33.])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# 전처리, 표준화
# minmax normalization : x = (x - min) / (max - min) => x / max
# robust normalization : x = (x - 중간값) / (3분위값 - 1분위값)
# standardization : x = x-mean / std

import numpy as np
# 평균

mean = np.mean(X_train, axis = 0)

# 표준편차
std = np.std(X_train, axis = 0) # 표준편차값

# 표준화값
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, activation = 'relu', input_shape = (3,)))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1)) 
model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                256
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,369
# Trainable params: 2,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
N_EPOCHS = 100
history = model.fit(X_train, y_train, epochs = N_EPOCHS, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1158 - mse: 0.1158 - val_loss: 0.1017 - val_mse: 0.1017
# Epoch 2/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1021 - mse: 0.1021 - val_loss: 0.1012 - val_mse: 0.1012
# Epoch 3/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1009 - mse: 0.1009 - val_loss: 0.0995 - val_mse: 0.0995
# Epoch 4/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.1009 - val_mse: 0.1009
# Epoch 5/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0995 - mse: 0.0995 - val_loss: 0.1000 - val_mse: 0.1000
# Epoch 6/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 7/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1003 - val_mse: 0.1003
# Epoch 8/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 9/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 10/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1009 - val_mse: 0.1009
# Epoch 11/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1005 - val_mse: 0.1005
# Epoch 12/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1012 - val_mse: 0.1012
# Epoch 13/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 14/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.1017 - val_mse: 0.1017
# Epoch 15/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 16/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1025 - val_mse: 0.1025
# Epoch 17/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0994 - mse: 0.0994 - val_loss: 0.0999 - val_mse: 0.0999
# Epoch 18/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0994 - mse: 0.0994 - val_loss: 0.1028 - val_mse: 0.1028
# Epoch 19/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 20/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1023 - val_mse: 0.1023
# Epoch 21/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 22/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1022 - val_mse: 0.1022
# Epoch 23/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 24/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1022 - val_mse: 0.1022
# Epoch 25/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 26/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1025 - val_mse: 0.1025
# Epoch 27/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1002 - val_mse: 0.1002
# Epoch 28/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1029 - val_mse: 0.1029
# Epoch 29/100
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1002 - val_mse: 0.1002
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0993 - mse: 0.0993
